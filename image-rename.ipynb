# %%
import os

# %% [markdown]
# #### Male

# %%
folder_path = "./dataset/image-dataset/train/male"

# %%
files = os.listdir(folder_path)

for index, file_name in enumerate(files, start=1):
    # get file extension
    ext = os.path.splitext(file_name)[1]
    
    # set new file name
    new_name = f"male_{index}{ext}"

    # full path for old and new file
    old_file = os.path.join(folder_path, file_name)
    new_file = os.path.join(folder_path, new_name)

    # rename file
    os.rename(old_file, new_file)


print("File rename completed")
# Out:
# File rename completed

# %% [markdown]
# #### Female

# %%
folder_path = "./dataset/image-dataset/train/female"

files = os.listdir(folder_path)

for index, file_name in enumerate(files, start=1):
    # get file extension
    ext = os.path.splitext(file_name)[1]
    
    # set new file name
    new_name = f"female_{index}{ext}"

    # full path for old and new file
    old_file = os.path.join(folder_path, file_name)
    new_file = os.path.join(folder_path, new_name)

    # rename file
    os.rename(old_file, new_file)


print("File rename completed")
# Out:
# File rename completed

# %% [markdown]
# #### Dog

# %%
folder_path = "./dataset/image-dataset/train/Dog"

files = os.listdir(folder_path)

for index, file_name in enumerate(files, start=1):
    # get file extension
    ext = os.path.splitext(file_name)[1]
    
    # set new file name
    new_name = f"dog_{index}{ext}"

    # full path for old and new file
    old_file = os.path.join(folder_path, file_name)
    new_file = os.path.join(folder_path, new_name)

    # rename file
    os.rename(old_file, new_file)


print("File rename completed")
# Out:
# File rename completed

# %% [markdown]
# #### Cat

# %%
folder_path = "./dataset/image-dataset/train/Cat"

files = os.listdir(folder_path)

for index, file_name in enumerate(files, start=1):
    # get file extension
    ext = os.path.splitext(file_name)[1]
    
    # set new file name
    new_name = f"cat_{index}{ext}"

    # full path for old and new file
    old_file = os.path.join(folder_path, file_name)
    new_file = os.path.join(folder_path, new_name)

    # rename file
    os.rename(old_file, new_file)


print("File rename completed")
# Out:
# File rename completed

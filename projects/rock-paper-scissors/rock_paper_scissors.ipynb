# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/machine-learning/rock-paper-scissors.v14i.yolov11.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.1e8561703c71365c0fed5b3bf9ae055c.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.6d343393e00bb5cdd53ba41620c2805d.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-212_jpg.rf.7653f90d0a71d91fb45908be2cfb2ef9.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.14f2adf12c2c9bc458d9495b8ec61076.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.6d5bc1bd3db6b53f0951763b33f8fe3c.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-214_jpg.rf.9fe36597c1505ea00935f4d1e1285ded.txt
#   inflating: train/labels/Screen-Recording-2023-03-11-at-9_48_18-PM_mov-215_jpg.rf.323f75af9cc2a439a8ed0b738864b30c.txt
# ...

# %%
# !yolo train model=yolo11m.pt data="/content/data.yaml" epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo val model="/content/runs/detect/train/weights/best.pt" data="/content/data.yaml"
# Out:
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1338.5±541.4 MB/s, size: 34.9 KB)
# val: Scanning /content/valid/labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% 576/576 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 36/36 [00:16<00:00,  2.16it/s]
#                    all        576        400      0.937      0.935      0.954      0.773
#                  Paper        132        139      0.956      0.941      0.958      0.786
#                   Rock        121        141      0.916       0.95       0.95      0.754
#               Scissors        116        120       0.94      0.913      0.953       0.78
# Speed: 0.7ms preprocess, 25.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/val
# ...

# %%
import cv2
import matplotlib.pyplot as plt
def show_image(image_path):
  image = cv2.imread(image_path)
  if image is None:
    print("Image not found")
    return

  plt.imshow(image)

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/304 /content/test/images/10e0gvm_jpg.rf.3b68a834fab647f30a57fc3ea92d4cd2.jpg: 640x640 (no detections), 36.8ms
# image 2/304 /content/test/images/15208484cellblock_jpg.rf.95cbda1e169a66105fbf2aa22959a73b.jpg: 640x640 (no detections), 36.9ms
# image 3/304 /content/test/images/19171_298_298_1_0_jpg.rf.0024dfb25d7b5a13a78e94fca47ef004.jpg: 640x640 (no detections), 36.8ms
# image 4/304 /content/test/images/20061004021831_jpg.rf.8667d8aa5599deb901289c024eed4313.jpg: 640x640 (no detections), 36.8ms
# image 5/304 /content/test/images/20220216_221550_jpg.rf.02a071a383151953fcf8671fc7fca3af.jpg: 640x640 1 Scissors, 36.8ms
# image 6/304 /content/test/images/20220216_221819_jpg.rf.295ebb583293f91f74e1700f0ab0639a.jpg: 640x640 1 Rock, 22.4ms
# ...

# %%
show_image("/content/runs/detect/predict/20220216_221856_jpg.rf.c551cb3856f480cba36d6aa58e3300cd.jpg")

# %%
show_image("/content/runs/detect/predict/IMG_5567_mp4-56_jpg.rf.7271d3b836d6215c40224f5bf5a8ad61.jpg")

# %%
show_image("/content/runs/detect/predict/IMG_7043_MOV-157_jpg.rf.30eede3e63f2f4b0584c162a0bc96ec0.jpg")

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/test/images/IMG_5636_MOV-38_jpg.rf.d7be4af05520f529b708f49fd21b5dc7.jpg"
# Out:
# Ultralytics 8.3.182 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,032,345 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/1 /content/test/images/IMG_5636_MOV-38_jpg.rf.d7be4af05520f529b708f49fd21b5dc7.jpg: 640x640 1 Scissors, 36.9ms
# Speed: 2.8ms preprocess, 36.9ms inference, 157.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/labels.jpg (deflated 30%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 19%)
#   adding: content/runs/detect/train/train_batch16162.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch16161.jpg (deflated 10%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 11%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 30%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 19%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 12%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 26%)
# ...

# %%
from google.colab import files
files.download("runs.zip")
